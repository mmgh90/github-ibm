# %% [markdown]
# <a href="https://colab.research.google.com/github/mmgh90/github-ibm/blob/master/PythonForEveryone_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 2: Programming with Numbers & Strings
#
#
# -----------------------------------------------------------------------------

# %% [markdown]
# ##**2.2 Arithmetic**

# %% [markdown]
# ###**2.2.1 Basic Operations**

# %%
a=110
b=50
c=a+b/2 # only b is divided by 2
print(c)
# Out:
# 135.0

# %% [markdown]
# ###**2.2.2 Powers**

# %%
n=2
d=b*(1+c/100)**n   # ** denotes power operation
print(d)
# Out:
# 276.12500000000006

# %% [markdown]
# ###**2.2.3 Floor Division & Remainder**
#
# The // operator computes floor division in which the remainder is discarded.
#
# The % operator (called modulus) computes the remainder of a floor division.

# %%
7//4
# Out:
# 1

# %%
7%4
# Out:
# 3

# %%
pennies=1729 #determine the value in dollar and cents
dollars=pennies//100 
cents=pennies%100
print("Value=",dollars, "and", cents)
# Out:
# Value= 17 and 29

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **2.2.4 Calling Functions**
#
# A function can return a value that can be used as if it were a literal value. The value returned by a function can be stored in a variable

# %%
d = -173
distance = abs(d)
print("distance=", distance) #or print("distance=", abs(d))
# Out:
# distance= 173

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
round(-7.234)
# Out:
# -7

# %%
round (-7.823)
# Out:
# -8

# %%
round(7.234, 2)
# Out:
# 7.23

# %% [markdown]
# ### **2.2.5. Mathematical Functions**
#
# Python has a standard library that provides functions and data types for your code. A library function must be imported into your program before it can be used.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import sqrt
y=sqrt(abs(d))
print(y)
# Out:
# 13.152946437965905

# %%
import math
y=math.sqrt(abs(d))
print(y)
# Out:
# 13.152946437965905

# %% [markdown]
# **NOTE:** Roundoff Errors

# %%
price = 4.35
quantity = 100
total = price * quantity # Should be 100 * 4.35 = 435 print(total)
print(total)
# Out:
# 434.99999999999994

# %%
print(round(total))
# Out:
# 435

# %% [markdown]
# **NOTE:** Combining Assignment and Arithmetic

# %%
cans=3
pots=4
pots=pots+cans
print (pots)
# Out:
# 7

# %%
cans=3
pots=4
pots += cans # pots =+ cans just prints cans!! #another example: pots *= cans or pots=pots*cans
print (pots)
# Out:
# 7

# %% [markdown]
# **NOTE:** Line Joining: If you have an expression that is too long to fit on a single line

# %%
a,b,c=(4,2,1)
x1 = ((b + sqrt(b ** 2 +4 * a * c)) 
/ (2 * a)) # Ok

# %%
x1 = (-b + sqrt(b ** 2 - 4 * a * c)) 
/ (2 * a) # Error: The first line is a complete statement, which the Python interpreter processes. The next line, / (2 * a), makes no sense by itself.
# Out:
#   File "<ipython-input-68-b3a3d80f88b5>", line 2
#     ((2, *, a), #, Error:, The, first, line, is, a, complete, statement,, which, the, Python, interpreter, processes., The, next, line,, /, (2, *, a),, makes, no, sense, by, itself.)
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## **2.4. Strings**
#
# The number of characters in a string is called the length of the string. You can compute the length of a string using Python’s ***len*** function. A string of length 0 is called the empty string. It contains no characters and is written
# as "" or ''.

# %% [markdown]
# ### **2.4.1. String Type**

# %%
length = len("World!") 
print(length)
# Out:
# 6

# %%
len('world!')
# Out:
# 6

# %%
greeting = "Hello" # A string can be stored in a variable
print(greeting)
# Out:
# Hello

# %%
message = 'He said "Hello"'
print(message)
# Out:
# He said "Hello"

# %% [markdown]
# ### **2.4.2. Concatenation & Repetition**
#
# Use the + operator to *concatenate* strings; that is, to put them together to yield a longer string. You cannot concatenate a string with a numerical value.

# %%
firstName = "Harry" 
lastName = "Morgan"
name = firstName + lastName
print(name)
# Out:
# HarryMorgan

# %%
name=firstName + " " + lastName
print(name)
# Out:
# Harry Morgan

# %%
name=firstName + ' ' + lastName
print(name)
# Out:
# Harry Morgan

# %% [markdown]
# A string can be repeated using the * operator.

# %%
dashes = "-" * 50
print(dashes)
message = "Echo..." 
print(message * 5)
# Out:
# --------------------------------------------------
# Echo...Echo...Echo...Echo...Echo...

# %% [markdown]
# ### **2.4.3. Converting Between Numbers & Strings**
#
# The ***str*** function converts an integer or floating-point value to a string.

# %%
# name = "Agent" + 1729 # Error: Can only concatenate strings

id = 1729
name = "Agent " + str(id)
print(name)
# Out:
# Agent 1729

# %% [markdown]
# The ***int*** and ***float*** functions convert a string containing a number to the numerical value.

# %%
id = int("1729")
id = id+11
print(id)
print()
price = float("17.29")
print (price)
# Out:
# 1740
#
# 17.29

# %% [markdown]
# **NOTE:** The string passed to the int or float functions can only consist of those characters that comprise a literal value of the indicated type.
#
# Blank spaces at the front or back will be ignored: int(" 1729 ") is still 1729.

# %%
value = float("17x29")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ad772942af95> in <module>()
# ----> 1 value = float("17x29")
#
# ValueError: could not convert string to float: '17x29'

# %% [markdown]
# ### **2.4.4. Strings & Characters**
#
# You can access the individual characters of a string based on their position within the string. This position is called the *index* of the character. String positions are counted starting with 0.
#
# ![image.png](data:image/png;base64,...)

# %%
name = "Harry"
first = name[0] 
last = name[4]
print(first)
print(last)
# Out:
# H
# y

# %% [markdown]
# The ***len*** function can be used to determine the position of the last index, or the last character in a string.

# %%
name = str(input("Name = "))
pos = len(name) - 1 
print(pos)      # Length of "Harry" is 5 
last = name[pos]          # last is set to "y"
print(last)
# Out:
# Name = Harry
# 4
# y

# %%
first = "Rodolfo"
second = "Sally"
initials = first[0] + "&" + second[0] 
print(initials)
# Out:
# R&S

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **2.4.5 String Methods**
#
# Unlike a function, which is a standalone operation, a method can only be applied to an object of the type for which it was defined.

# %%
name = "John Smith"
uppercaseName = name.upper()
print(uppercaseName)
print()
print(name.lower())
# Out:
# JOHN SMITH
#
# john smith

# %%
name2 = name.replace("John", "Jane")
print(name2)
# Out:
# Jane Smith

# %% [markdown]
# **NOTE:** Character Values
#
# A character is stored internally as an integer value. You can find the values of the characters that are used in Western European languages in Appendix D. For example, if you look up the value for the character "H", you can see that it is actually encoded as the number 72.

# %%
print("The letter H has a code of", ord("H")) 
print("Code 97 represents the character", chr(97))
# Out:
# The letter H has a code of 72
# Code 97 represents the character a

# %% [markdown]
# **NOTE:** Escape Sequences
#
# The sequence **\\"** is called an escape sequence. The backslash is not included in the string. It indicates that the quotation mark that follows should be a part of the string and not mark the end of the string.

# %%
print("You're \"Welcome\"")
# Out:
# You're "Welcome"

# %% [markdown]
# Another common escape sequence is **\n**, which denotes a newline character.

# %%
print("*\n**\n***")
# Out:
# *
# **
# ***

# %% [markdown]
# ## **2.5 Input & Output**

# %% [markdown]
# ### **2.5.1 User Input**
#
# When a program asks for user input, it should first print a message (called *prompt*) that tells the user which input is expected. The input function displays the string argument in the console window and places the
# cursor on the same line, immediately following the string.

# %%
first = input("Enter your first name: ")
second = input("Enter your significant other's first name: ")
initials = first[0] + "&" + second[0] 
print(initials)
# Out:
# Enter your first name: mahdi
# Enter your significant other's first name: reza
# m&r

# %% [markdown]
# ### **2.5.2 Numerical Input**
#
# To read an integer or floating-point value, use the input function followed by the int or float function.

# %%
userInput = input("Please enter the number of bottles: ") 
bottles = int(userInput)
# Out:
# Please enter the number of bottles: 25

# %% [markdown]
# ### **2.5.3 Formatted Output**
#
# When you print the result of a computation, you often want to control its appearance. For example, the following commands display the price with two and four digits after the decimal point. The construct **%10.2f** is called a ***format specifier***: it describes how a value should be formatted. The letter f at the end of the format specifier indicates that we are formatting a floating-point value. Use ***d*** for an **integer** value and ***s*** for a **string**.

# %%
price=1.22235434598479
print("%.2f" % price)
print("%.4f" % price)
print()
print("Price per liter:%10.2f" % price)
# Out:
# 1.22
# 1.2224
#
# Price per liter:      1.22

# %% [markdown]
# **NOTE:** when the values left and right of the operator are both numbers, the % symbol is used to compute the remainder of floor division. If the value on the left is a string, then the % symbol becomes the *string format operator*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **NOTE:** You can format multiple values with a single string format operation, but you must enclose them in parentheses and separate them by commas.

# %%
title1 = "Quantity:"
title2 = "Price:"
print("%10s %10d" % (title1, 24)) 
print("%10s %10.2f" % (title2, 17.29))
print()
print("%-10s %10d" % (title1, 24)) 
print("%-10s %10.2f" % (title2, 17.29))
# Out:
#  Quantity:         24
#     Price:      17.29
#
# Quantity:          24
# Price:          17.29

# %%
# Define constant for pack size. 
CANS_PER_PACK = 6
# Obtain price per pack and can volume.
userInput = input("Please enter the price for a six-pack: ") 
packPrice = float(userInput)
userInput = input("Please enter the volume for each can (in ounces): ") 
canVolume = float(userInput)
# Compute pack volume.
packVolume = canVolume * CANS_PER_PACK
# Compute and print price per ounce. 
pricePerOunce = packPrice / packVolume 
print("Price per ounce: %8.2f" % pricePerOunce)
# Out:
# Please enter the price for a six-pack: 23
# Please enter the volume for each can (in ounces): 23
# Price per ounce:     0.17

# %% [markdown]
# **NOTE:** Don't Wait to Convert!

# %%
unitPrice = input("Enter the unit price: ")
price1 = float(unitPrice)
price2= 12 * float(unitPrice) # Bad style
print(price1, price2)
# Out:
# Enter the unit price: 20
# 20.0 240.0

# %%
unitPriceInput = input("Enter the unit price: ")
unitPrice = float(unitPriceInput) # Do this immediately after reading the input price1 = unitPrice
price2 = 12 * unitPrice

# %%
unitPrice = float(input("Enter the unit price: ")) # even better way !
# Out:
# Enter the unit price: 12
